# %%
from linescan import vis_tools
from pathlib import Path

# %% [markdown]
# # 2-channel images

# %% [markdown]
# ## DNA second

# %%
channels = ["CENP-A", "H2B-mCherry"]
images = [
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell 15-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell 18-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell11-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell14-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell17-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell8-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell9-prometa.tif",
]
rois = [
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#15-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#18-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#11-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#14-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#17-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#8-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#9-Prometa.zip",
]

# %%
vis_tools.plot_image_and_profiles(
    images[0], rois[0], number_of_channels=2, disp_channels=[1,2]
)
# Out:
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/clanger/Desktop/github/linescan_tool/test_vis.ipynb Cell 5' in <module>
# ----> <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_vis.ipynb#ch0000004?line=0'>1</a> vis_tools.plot_image_and_profiles(
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_vis.ipynb#ch0000004?line=1'>2</a>     images[0], rois[0], number_of_channels=2, disp_channels=[1,2]
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_vis.ipynb#ch0000004?line=2'>3</a> )
#
# File ~/Desktop/github/linescan_tool/linescan/vis_tools.py:18, in plot_image_and_profiles(image_path, roi_path, disp_channels, number_of_channels)
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=10'>11</a> """Plots every z-slice that has at least one linescan.
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=11'>12</a> Colors represent the particular line drawn on the image.
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=12'>13</a> Channels are displayed one after each other.
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=13'>14</a> Channels can be normalized and the fitting and peak calling can be displayed.
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=14'>15</a> Further lines can be aligned according to the offset of peak in a praticular channel.
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=15'>16</a> """
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=16'>17</a> if number_of_channels == 2:
# ---> <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=17'>18</a>     plot_image_and_profiles_2c(image_path, roi_path, disp_channels=disp_channels)
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=18'>19</a> elif number_of_channels >= 3:
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=19'>20</a>     plot_image_and_profiles_3c(image_path, roi_path, disp_channels=disp_channels, number_of_channels=number_of_channels)
#
# File ~/Desktop/github/linescan_tool/linescan/vis_tools.py:69, in plot_image_and_profiles_2c(image_path, roi_path, disp_channels)
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=65'>66</a> # Draw images with lines for the set of channels to display
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=66'>67</a> for disp_num, disp_channel in enumerate(disp_channels):
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=67'>68</a>     axs[slice_num, number_of_channels + disp_num].imshow(
# ---> <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=68'>69</a>         image[img_slice, disp_channel, :, :], cmap="gray"
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=69'>70</a>     )
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=70'>71</a>     for _, item in roi.items():
#      <a href='file:///~/Desktop/github/linescan_tool/linescan/vis_tools.py?line=71'>72</a>         if item["position"]["slice"] == img_slice:
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
vis_tools.plot_line_profiles(
    images[0], rois[0], number_of_channels=2, disp_channels=[0,1]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/clanger/Desktop/github/linescan_tool/test_vis.ipynb Cell 6' in <module>
# ----> <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_vis.ipynb#ch0000005?line=0'>1</a> vis_tools.plot_line_profiles(
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_vis.ipynb#ch0000005?line=1'>2</a>     images[0], rois[0], number_of_channels=2, disp_channels=[0,1]
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_vis.ipynb#ch0000005?line=2'>3</a> )
#
# NameError: name 'vis_tools' is not defined

# %% [markdown]
# ## DNA first

# %%
channels = ["H2B-mCherry", "CENPA"]

# %%
rois = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell1_ROI.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell2.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell3.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell4.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell5.zip",
]

# %%
images = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell1.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell2.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell3.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell4.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell5.tif",
]

# %%
vis_tools.plot_line_profiles(
    images[0], rois[0], number_of_channels=2, disp_channels=[0,1]
)

# %%
vis_tools.plot_image_and_profiles(
    images[0], rois[0], number_of_channels=2, disp_channels=[0,1]
)

# %% [markdown]
# # 3-channel images

# %%
rois_3c = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#1_CENPA_CREST.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#2_CENPA_CREST.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#4_CENPA_CREST.zip",
]
images_3c = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #01.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #02.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #04.tif",
]
channels = ["CENPA", "CREST", "DAPI"]

# %%
vis_tools.plot_image_and_profiles(
    images_3c[0], rois_3c[0], number_of_channels=3, disp_channels=[2]
)
# Out:
# 3
# [2]
# [27, 33, 43, 62]

# %%
vis_tools.plot_line_profiles(
    images_3c[0], rois_3c[0], number_of_channels=3, disp_channels=[0,1,2]
)

# %% [markdown]
# # 4-channel images

# %%
from linescan import vis_tools
from pathlib import Path

# %%
rois_4c = [str(Path.home())+"/gerlich/experiments/Experiments_005400/005406/plot_profiles/wapl_dep/Scc1_EdU_Hoechst_211206_5348_2096_g2_18h_rel_wap_dep_6h_hemi_stlc_zoom4_8_cycb1_scc1_edu_hoechst_rep1-03-72-74.tif_registered.tif/positions.zip"]
images_4c = [str(Path.home())+"/gerlich/experiments/Experiments_005400/005406/images/211206_5348_2096_g2_18h_rel_wap_dep_6h_hemi_stlc_zoom4_8_cycb1_scc1_edu_hoechst_rep1-03-72-74.tif_registered.tif"]
channels = ["cyclinb1", "scc1", "edu", "hoechst"]

# %%
vis_tools.plot_image_and_profiles(
    images_4c[0], rois_4c[0], number_of_channels=4, disp_channels=[0,1,2,3]
)
# Out:
# 4
# [0, 1, 2, 3]
# [18]

# %%
vis_tools.plot_image_and_profiles(
    images_3c[0], rois_3c[0], number_of_channels=3, disp_channels=[0,1,2]
)
# Out:
# 3
# [0, 1, 2]
# [27, 33, 43, 62]

# %%
vis_tools.plot_line_profiles(
    images_4c[0], rois_4c[0], number_of_channels=4, disp_channels=[1,2,3]
)
