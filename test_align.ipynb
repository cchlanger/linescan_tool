# %%
from linescan import vis_tools
from linescan import align_tools
from pathlib import Path

# %% [markdown]
# # 2-channel images

# %% [markdown]
# ## DNA second

# %%
channels = ["CENP-A", "H2B-mCherry"]
images = [
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell 15-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell 18-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell11-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell14-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell17-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell8-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Cell9-prometa.tif",
]
rois = [
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#15-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#18-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#11-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#14-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#17-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#8-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/RoiSet#9-Prometa.zip",
]

# %%
results = align_tools.linescan(
    images,
    rois,
    channels,
    align_channel=1,
    number_of_channels=2,
    align_method="half_max"
)
results
# Out:
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# /home/clanger/miniconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 41.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
#       CENP-A  H2B-mCherry
# 0  -0.049088          0.0
# 1   0.154765          0.0
# 2   0.056218          0.0
# 3  -0.086660          0.0
# 4   0.027085          0.0
# 5  -0.100253          0.0
# 6   0.080912          0.0
# 7  -0.176098          0.0
# 8   0.055562          0.0
# 9   0.168341          0.0
# 10  0.038249          0.0
# 11 -0.145269          0.0
# 12  0.008294          0.0
# 13 -0.019154          0.0
# 14 -0.141912          0.0
# 15 -0.039067          0.0
# 16 -0.091166          0.0
# 17  0.019331          0.0
# 18 -0.006791          0.0
# 19 -0.663860          0.0
# 20  0.032656          0.0
# 21  0.068715          0.0
# 22  0.052784          0.0
# 23 -0.004983          0.0
# 24 -0.050061          0.0
# 25 -0.078599          0.0
# 26 -0.073366          0.0
# 27  0.137924          0.0
# 28 -0.020339          0.0
# 29 -0.088525          0.0
# 30 -0.060034          0.0
# 31 -0.122303          0.0
# 32  0.037060          0.0
# 33  0.170940          0.0
# 34  0.049571          0.0
# 35  0.160583          0.0
# 36 -0.021538          0.0
# 37 -0.020364          0.0
# 38  0.099936          0.0
# 39 -0.130709          0.0
# 40 -0.069554          0.0
# 41 -0.050259          0.0
# 42 -0.054702          0.0

# %% [markdown]
# ## DNA first

# %%
channels = ["H2B-mCherry", "CENPA"]

# %%
rois = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell1_ROI.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell2.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell3.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell4.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell5.zip",
]

# %%
images = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell1.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell2.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell3.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell4.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell5.tif",
]

# %%
results = align_tools.linescan(
    images,
    rois,
    channels,
    align_channel=0,
    number_of_channels=2,
    align_method="half_max"
)
results
# Out:
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/clanger/Desktop/github/linescan_tool/test_align.ipynb Cell 10' in <module>
# ----> <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=0'>1</a> results = align_tools.linescan(
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=1'>2</a>     images,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=2'>3</a>     rois,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=3'>4</a>     channels,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=4'>5</a>     align_channel=0,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=5'>6</a>     number_of_channels=2,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=6'>7</a>     align_method="half_max"
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=7'>8</a> )
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000025?line=8'>9</a> results
#
# File ~/Desktop/github/linescan_tool/linescan/align_tools.py:35, in linescan(image_path, roi_path, channels, number_of_channels, align_channel, align_method, normalize, pixelsize, align)
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=22'>23</a> def linescan(
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=23'>24</a>     image_path,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=24'>25</a>     roi_path,
#    (...)
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=31'>32</a>     align=True,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=32'>33</a> ):
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=33'>34</a>     if (number_of_channels == 2) and (align_method == "half_max"):
# ---> <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=34'>35</a>         result_df = linescan_half_alingne_lagacy_2c_dnafirst(
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=35'>36</a>             image_path,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=36'>37</a>             roi_path,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=37'>38</a>             channels,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=38'>39</a>             number_of_channels=2,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=39'>40</a>             align_channel=align_channel,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=40'>41</a>             normalize=True,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=41'>42</a>             pixelsize=pixelsize,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=42'>43</a>             align=align,
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=43'>44</a>         )
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=44'>45</a>         #print(result_df)
#      <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=45'>46</a>         return result_df
#
# File ~/Desktop/github/linescan_tool/linescan/align_tools.py:158, in linescan_half_alingne_lagacy_2c_dnafirst(image_path, roi_path, channels, number_of_channels, align_channel, normalize, pixelsize, align)
#     <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=153'>154</a> # print(peaks)
#     <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=154'>155</a> # print(heights)
#     <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=156'>157</a> heights = heights["peak_heights"].tolist()
# --> <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=157'>158</a> biggest_peak2 = heights.index(max(heights))
#     <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=158'>159</a> peak_point = peaks[biggest_peak2]
#     <a href='file:///home/clanger/Desktop/github/linescan_tool/linescan/align_tools.py?line=159'>160</a> channel_max.append((peak_point - offset) * scaling)
#
# ValueError: max() arg is an empty sequence

# %% [markdown]
# # 3-channel images

# %%
rois_3c = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#1_CENPA_CREST.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#2_CENPA_CREST.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#4_CENPA_CREST.zip",
]
images_3c = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #01.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #02.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #04.tif",
]
channels = ["CENPA", "CREST", "DAPI"]

# %%
results = align_tools.linescan(
    images_3c,
    rois_3c,
    channels,
    align_channel=2,
    number_of_channels=3,
    align_method="half_max"
)
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/clanger/Desktop/github/linescan_tool/test_align.ipynb Cell 13' in <module>
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=0'>1</a> results = align_tools.linescan(
# ----> <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=1'>2</a>     images,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=2'>3</a>     rois,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=3'>4</a>     channels,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=4'>5</a>     align_channel=2,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=5'>6</a>     number_of_channels=3,
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=6'>7</a>     align_method="half_max"
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=7'>8</a> )
#       <a href='vscode-notebook-cell:/home/clanger/Desktop/github/linescan_tool/test_align.ipynb#ch0000026?line=8'>9</a> results
#
# NameError: name 'images' is not defined

# %% [markdown]
# # 4-channel images

# %%
from linescan import vis_tools
from pathlib import Path

# %%
rois_4c = [str(Path.home())+"/gerlich/experiments/Experiments_005400/005406/plot_profiles/wapl_dep/Scc1_EdU_Hoechst_211206_5348_2096_g2_18h_rel_wap_dep_6h_hemi_stlc_zoom4_8_cycb1_scc1_edu_hoechst_rep1-03-72-74.tif_registered.tif/positions.zip"]
images_4c = [str(Path.home())+"/gerlich/experiments/Experiments_005400/005406/images/211206_5348_2096_g2_18h_rel_wap_dep_6h_hemi_stlc_zoom4_8_cycb1_scc1_edu_hoechst_rep1-03-72-74.tif_registered.tif"]
channels = ["cyclinb1", "scc1", "edu", "hoechst"]

# %%
#TBA not supported yet
