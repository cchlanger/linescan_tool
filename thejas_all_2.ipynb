# %%
from linescan import vis_tools
from linescan import align_tools
from pathlib import Path
import pandas as pd

# %% [markdown]
# # Thejas Summary
# ## Controls:
# ### Expected overlap: CENPA - CREST
# - delta SMC4 cells - channels [CENPA,CREST,DAPI]

# %%
roi_paths = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#1_CENPA_CREST.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#2_CENPA_CREST.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#4_CENPA_CREST.zip",
]
image_names = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #01.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #02.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #04.tif",
]
channels = ["CENPA", "CREST", "DAPI"]

# %% [markdown]
# - long lines

# %%
roi_paths = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#1.1_CENPA_CREST.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#2.1_CENPA_CREST.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI#4.1_CENPA_CREST.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell1_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell11_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell12_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell13_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell15_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell2_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell4_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell5_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell6_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell7_CREST_CENP-A-replicate2.zip",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/ROI_Cell9_CREST_CENP-A-replicate2.zip",  
]
image_names = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #01.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #02.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/Airy Scan_CENPA_CREST_Noc +aux.czi #04.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell1_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell11_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell12_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell13_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell15_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell2_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell4_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell5_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell6_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell7_CREST_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/CENP-A+CREST/Cell9_CREST_CENP-A-replicate2.tif",  
]
channels = ["CENPA", "CREST", "DAPI"]

# %%
# for index, image in enumerate(image_names): 
#     vis_tools.plot_image_and_profiles(
#         image_names[index], roi_paths[index], number_of_channels=3, disp_channels=[0,1,2]
#     )

# %%
results = align_tools.linescan(
    image_names,
    roi_paths,
    channels,
    align_channel=2,
    number_of_channels=3,
    align_method="half_max"
)
results
# Out:
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# ...

# %% [markdown]
# ### Slight shift: INCENP more internal then CENPA
# - delta SMC4 - channels ["CENPA", "INCENP", "DAPI"]

# %%
roi_paths = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#4_INCENP_CENP-A_ No treatment.zip", 
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#6_INCENP_CENP-A_ No treatment.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/ROI_Cell1_INCENP_CENP-A-replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/ROI_Cell10_INCENP_CENP-A-replicate2.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/ROI_Cell2_INCENP_CENP-A-replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/ROI_Cell3_INCENP_CENP-A-replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/ROI_Cell5_INCENP_CENP-A-replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/ROI_Cell8_INCENP_CENP-A-replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/ROI_Cell9_incenp_CENP-A-replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/ROISet_Cell7-INCENP-CENP-A-replicate2.zip",   
]
image_names = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czi #4.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czi #6.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/Cell1_INCENP_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/Cell10_INCENP_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/Cell2_INCENP_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/Cell3_INCENP_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/Cell5_INCENP_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/Cell7_INCENP_CENP-A-replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/Cell8_INCENP_CENP-A-replicate2.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005300/005372/Analysis/Analysis Replicate2/INCENP-A+CENP-A/Cell9_INCENP_CENP-A-replicate2.tif",   
]
channels = ["CENPA", "INCENP", "DAPI"]

# %% [markdown]
# - long lines

# %%
roi = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#4.1_INCENP_CENP-A_ No treatment.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#6.1_INCENP_CENP-A_ No treatment.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#1.1_INCENP_CENP-A_ No treatment.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#2.1_INCENP_CENP-A_ No treatment.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#5.1_INCENP_CENP-A_ No treatment.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#7.1_INCENP_CENP-A_ No treatment.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#8.1_INCENP_CENP-A_ No treatment.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#9.1_INCENP_CENP-A_ No treatment.zip",
]
image_names = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czi #4.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czi #6.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czi #1.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #02.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czii #5.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czi #7.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czi #8.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A_No treatment-Airyscan Processing.czi #9.tif",
]
channels = ["CENPA", "INCENP", "DAPI"]

# %% [markdown]
# - siRNA CENPC-T

# %%
roi_paths = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#2_INCENP_CENP-A_siCENP-C+T(8+16).zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#3_INCENP_CENP-A_siCENP-C+T(8+16).zip",
]
image_names = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #02.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #03.tif",
]
channels = ["CENPA", "INCENP", "DAPI"]

# %% [markdown]
# - long lines

# %%
roi = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#2.1_INCENP_CENP-A_siCENP-C+T(8+16).zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#3.1_INCENP_CENP-A_siCENP-C+T(8+16).zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#5.1_INCENP_CENP-A_siCENP-C+T(8+16).zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#06.1_INCENP_CENP-A_siCENP-C+T(8+16).zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#08.1_INCENP_CENP-A_siCENP-C+T(8+16).zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#09.1_INCENP_CENP-A_siCENP-C+T(8+16).zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/RoiSet#10.1_INCENP_CENP-A_siCENP-C+T(8+16).zip",
]
image_names = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #02.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #03.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi  #05.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #06.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #08.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #09.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/211214_INCENP_CENP-A-siCENPC+T-8+16-Airyscan Processing.czi #10.tif",
]
channels = ["CENPA", "INCENP", "DAPI"]

# %% [markdown]
# ### AluI digested cells (see if CENPA still at the surface)
# - delta SmC4 AluI digested cells

# %%
roi = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell1_ROI.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell2.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell3.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell4.zip",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/ROI-AluI digest-cell5.zip",
]
image_names = [
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell1.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell2.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell3.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell4.tif",
    str(Path.home())
    + "/gerlich/members/ThejaswiNagaraju/Surface Targetting of CENPA- For Christoph/AluI digest-cell5.tif",
]
channels = ["H2B-mCherry", "CENPA"]

# %% [markdown]
# ### Prometaphase - WT - unperturbed

# %%
from linescan import vis_tools
from linescan import align_tools
from pathlib import Path

# %%
roi = [
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/RoiSet#15-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/RoiSet#18-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/RoiSet#11-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/RoiSet#14-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/RoiSet#17-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/RoiSet#8-Prometa.zip",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/RoiSet#9-Prometa.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#1_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#11_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#12_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#2_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#3_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#4_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#5_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#6_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#8_replicate2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/RoiSet#9_replicate2.zip",      
]
image_names = [
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/Cell 15-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/Cell 18-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/Cell11-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/Cell14-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/Cell17-prometa.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/Cell8-prometa.tif",
    str(Path.home())
        + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate1_unpertubed mitotic_prometa/Cell9-prometa.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell1_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell11_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell12_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell2_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell3_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell4_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell5_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell6_replicate2.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell8_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005404/Analysis-Unpertubed Mitotic/Replicate2- Unpertubed mitotic_prometa/Cell9_replicate2.tif",]   

channels = ["H2B-mCherry", "CENPA"]

# %%
results = align_tools.linescan(
    image_names,
    roi,
    channels,
    align_channel=1,
    number_of_channels=2,
    align_method="half_max"
)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(results)
# Out:
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# ...

# %%
type(results)

# %% [markdown]
# TetO-TetR-GFP signals

# %%
from linescan import vis_tools
from linescan import align_tools
from pathlib import Path

# %%
roi = [
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/RoiSet#1.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/RoiSet#2.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/RoiSet#3.roi",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/RoiSett#4.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/RoiSett#5.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/RoiSett#8.roi",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Roi-Cell1.roi", 
    str(Path.home())
    
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Roi-Cell11.roi", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Roi-Cell14.roi", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/RoiSet#16.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Roi-Cell2.roi", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Roi-Cell3.roi", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Roi-Cell6.roi", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/RoiSet#7.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/RoiSet#8.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Roi-Cell9.roi", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/RoiSet#4.zip", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Roi-Cell5.roi",]  

# + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/RoiSet#10.zip", 
#     str(Path.home())

image_names = [
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/Cell1.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/Cell2.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/Cell3.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/Cell4.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/Cell5.tif",
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 1/Cell8.tif",  
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 1_replicate2.tif", 
    str(Path.home())
   
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 11_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 14_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 16_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 2_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 3_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 6_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 7_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 8_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 9_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell4_replicate2.tif", 
    str(Path.home())
    + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell5_replicate2.tif",   ]  

#  + "/gerlich/experiments/Experiments_005400/005486/Analysis/Replicate 2/Cell 10_replicate2.tif", 
#     str(Path.home())

channels = ["TetR", "H2B-mCherry"]

# %%
results = align_tools.linescan(
    image_names,
    roi,
    channels,
    align_channel=0,
    number_of_channels=2,
    align_method="half_max"
)
results
# Out:
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# ...

# %%
# vis_tools.plot_image_and_profiles(
#         image_names[13], roi[13], number_of_channels=2, disp_channels=[0,1]
#     )

vis_tools.plot_line_profiles(
        image_names[13], roi[13], number_of_channels=2, disp_channels=[0,1]
    )
# Out:
# WARNING:tifffile.tifffile:TiffPage 0: TypeError: read_bytes() missing 3 required positional arguments: 'dtype', 'count', and 'offsetsize'
# [258.5, 200.8333282470703]
# [258.5, 200.8333282470703]
# [263.1666564941406, 224.1666717529297]
# [263.1666564941406, 224.1666717529297]
